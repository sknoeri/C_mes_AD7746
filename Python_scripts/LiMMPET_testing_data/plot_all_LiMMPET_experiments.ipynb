# %%
import glob, os
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
import numpy as np
from scipy import optimize

retval = os.getcwd()
print("current working direct %s" % retval)
# mypath = "C:\\Users\\sean\\Box\\2019-2020\\Research\\LIMMPET\\Experimental Data\\test\\"
mypath = '/Users/mackenzie/Desktop/LiMMPET testing data'


# Here's how:

# To navigate to a directory
#os.chdir(mypath)

# To loop over all text files in a directy and plot
file = (glob.glob("*.txt"))
substring = "_v3_"

print(np.shape(file))
print(file[2])
# Out:
# current working direct /Users/mackenzie/Desktop/LiMMPET testing data
# (35,)
# 8.12.19_v3_test8.txt

# %%
for index, item in enumerate(file, start=1):
    
    fullstring = file[index]
    
    if substring in fullstring:
        datax, datay = np.loadtxt(item, dtype = float, skiprows=1, unpack=True)
        
        if np.amax(np.abs(datax)) > 1: 
            plt.figure(1)
            plt.scatter(datay,datax)
            plt.suptitle("{}".format(item))
            plt.xlabel('Time (s)')
            plt.ylabel('Potential (V)')
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/r8/hk5l1nm14mv_s5ykg8b6z2_00000gn/T/ipykernel_2885/796277125.py in <module>
#       1 for index, item in enumerate(file, start=1):
#       2
# ----> 3     fullstring = file[index]
#       4
#       5     if substring in fullstring:
#
# IndexError: list index out of range
